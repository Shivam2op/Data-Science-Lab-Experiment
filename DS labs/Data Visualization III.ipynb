# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\Manoj\CODE\Python\Machine Learning\Data_Sets\IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print("Features and their types:")
print(df.dtypes)
# Out:
# Features and their types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
df.boxplot()
plt.title('Boxplot of Iris Dataset Features')
plt.ylabel('Feature Values')
plt.show()

# %%
numeric_columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
numeric_data = df[numeric_columns]

# Identify outliers
outliers = pd.DataFrame(columns=numeric_data.columns)

for column in numeric_data.columns:
    lower_threshold = numeric_data[column].quantile(0.25) - 1.5 * (numeric_data[column].quantile(0.75) - numeric_data[column].quantile(0.25))
    upper_threshold = numeric_data[column].quantile(0.75) + 1.5 * (numeric_data[column].quantile(0.75) - numeric_data[column].quantile(0.25))
    column_outliers = numeric_data[(numeric_data[column] < lower_threshold) | (numeric_data[column] > upper_threshold)]
    outliers = pd.concat([outliers, column_outliers])

print("Identified outliers:")
print(outliers)
# Out:
# Identified outliers:
#     sepal_length  sepal_width  petal_length  petal_width
# 15           5.7          4.4           1.5          0.4
# 32           5.2          4.1           1.5          0.1
# 33           5.5          4.2           1.4          0.2
# 60           5.0          2.0           3.5          1.0
